# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv('df_1.csv')
df_2 = pd.read_csv('df_2.csv')
df_3 = pd.read_csv('df_3.csv')

# %%
df_1_c = df_1.copy()
df_2_c = df_2.copy()
df_3_c = df_3.copy()

# %%
df_1_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130501 entries, 0 to 130500
# Data columns (total 84 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   acc_x_dashboard_left           130501 non-null  float64
#  1   acc_y_dashboard_left           130501 non-null  float64
#  2   acc_z_dashboard_left           130501 non-null  float64
#  3   acc_x_above_suspension_left    130501 non-null  float64
#  4   acc_y_above_suspension_left    130501 non-null  float64
#  5   acc_z_above_suspension_left    130501 non-null  float64
#  6   acc_x_below_suspension_left    130501 non-null  float64
#  7   acc_y_below_suspension_left    130501 non-null  float64
#  8   acc_z_below_suspension_left    130501 non-null  float64
#  9   gyro_x_dashboard_left          130501 non-null  float64
#  10  gyro_y_dashboard_left          130501 non-null  float64
#  11  gyro_z_dashboard_left          130501 non-null  float64
# ...

# %%
df = pd.concat([df_1_c, df_2_c, df_3_c], axis = 0)

# %%
df
# Out:
#        acc_x_dashboard_left  acc_y_dashboard_left  acc_z_dashboard_left  \
# 0                 -0.955286             -0.234632             15.035586
# 1                 -1.021127              0.319626             14.189236
# 2                 -1.199495              0.821211             14.987702
# 3                 -1.048660              0.141258             15.090653
# 4                 -0.821211             -0.009577             13.285425
# ...                     ...                   ...                   ...
# 95196             -0.751779             -1.242591             13.591883
# 95197             -1.362301             -1.508347             13.874399
# 95198             -1.355118             -0.222661             14.563929
# 95199             -1.169568             -1.921347             13.500903
# 95200             -0.715866             -0.562637             14.935030
#
#        acc_x_above_suspension_left  acc_y_above_suspension_left  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# acc_x_dashboard_left             float64
# acc_y_dashboard_left             float64
# acc_z_dashboard_left             float64
# acc_x_above_suspension_left      float64
# acc_y_above_suspension_left      float64
# acc_z_above_suspension_left      float64
# acc_x_below_suspension_left      float64
# acc_y_below_suspension_left      float64
# acc_z_below_suspension_left      float64
# gyro_x_dashboard_left            float64
# gyro_y_dashboard_left            float64
# gyro_z_dashboard_left            float64
# gyro_x_above_suspension_left     float64
# gyro_y_above_suspension_left     float64
# gyro_z_above_suspension_left     float64
# gyro_x_below_suspension_left     float64
# gyro_y_below_suspension_left     float64
# gyro_z_below_suspension_left     float64
# mag_x_dashboard_left             float64
# mag_y_dashboard_left             float64
# mag_z_dashboard_left             float64
# mag_x_above_suspension_left      float64
# mag_y_above_suspension_left      float64
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df.shape
# Out:
# (344203, 84)

# %%
lst = df.select_dtypes(include = ['number']).columns
plt.figure(figsize = (15,15))
for i, v in enumerate(lst,1):
    plt.subplot(28,3,i)
    sns.histplot(df[v], kde = True, stat = 'density')
    plt.title(f'Distribucion {v}')
    plt.xlabel(v)
    plt.ylabel('Densidad')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_125648/1426170363.py:10: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df[lst]['acc_magnitude_avg_Target']
# Out:
# 0        12.658668
# 1        10.589358
# 2        11.340244
# 3        12.388905
# 4        11.963998
#            ...
# 95196    11.399334
# 95197    11.675602
# 95198    11.542026
# 95199    11.315137
# 95200    11.363644
# Name: acc_magnitude_avg_Target, Length: 344203, dtype: float64

# %%
matrix_corr = df[lst].corr()
plt.figure(figsize = (10,10))
plt.title('Matriz de correlacion')
sns.heatmap(matrix_corr, cmap = 'YlGnBu')
plt.show()

# %%
matrix_corr = df[lst].corr()
plt.figure(figsize = (10,10))
plt.title('Matriz de correlacion')
sns.heatmap(matrix_corr, cmap = 'coolwarm')
plt.show()

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#        acc_x_dashboard_left  acc_y_dashboard_left  acc_z_dashboard_left  \
# 0                 -0.955286             -0.234632             15.035586
# 1                 -1.021127              0.319626             14.189236
# 2                 -1.199495              0.821211             14.987702
# 3                 -1.048660              0.141258             15.090653
# 4                 -0.821211             -0.009577             13.285425
# ...                     ...                   ...                   ...
# 95196             -0.751779             -1.242591             13.591883
# 95197             -1.362301             -1.508347             13.874399
# 95198             -1.355118             -0.222661             14.563929
# 95199             -1.169568             -1.921347             13.500903
# 95200             -0.715866             -0.562637             14.935030
#
#        acc_x_above_suspension_left  acc_y_above_suspension_left  \
# ...

# %%
matrix_corr['acc_magnitude_avg_Target'].sort_values(ascending=False).head(10)
# Out:
# acc_magnitude_avg_Target       1.000000
# regular_road                   0.031366
# cobblestone_road               0.022657
# temp_above_suspension_right    0.017083
# unpaved_road                   0.015131
# temp_above_suspension_left     0.014374
# gyro_magnitude_avg             0.013723
# temp_below_suspension_right    0.009795
# temp_below_suspension_left     0.009275
# bad_road                       0.008243
# Name: acc_magnitude_avg_Target, dtype: float64
